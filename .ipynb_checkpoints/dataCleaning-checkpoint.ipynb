# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./data/CSV/rawData.csv')

# %%
df.shape
# Out:
# (7777, 16)

# %%
df.head(1)
# Out:
#            Car    Year     Price      Color   Fuel Origin   License  \
# 0  كيا اوبتيما  2014.0  100000.0  أبيض عاجي  بنزين  خصوصي  فلسطينية
#
#         Gear     Glass   Power  Meter Passengers   Payment       Sale  \
# 0  اوتوماتيك  الكتروني  2000.0  75000        4+1  نقدا فقط  للبيع فقط
#
#   Previous_owners                                          Additions
# 0         يد اولى  مُكيّف,إغلاق مركزي,جهاز إنذار,مسجل,فتحة سقف,جن...

# %%
df.columns
# Out:
# Index(['Car', 'Year', 'Price', 'Color', 'Fuel', 'Origin', 'License', 'Gear',
#        'Glass', 'Power', 'Meter', 'Passengers', 'Payment', 'Sale',
#        'Previous_owners', 'Additions'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Car                 913
# Year                913
# Price               913
# Color               913
# Fuel                913
# Origin              913
# License             913
# Gear                913
# Glass               913
# Power               913
# Meter              2854
# Passengers         1690
# Payment             913
# Sale                913
# Previous_owners    2563
# Additions           501
# dtype: int64

# %%
threshold = 8
df.dropna(thresh=df.shape[1] - threshold + 1, inplace=True)

# %%
df.isna().sum()
# Out:
# Car                   0
# Year                  0
# Price                 0
# Color                 0
# Fuel                  0
# Origin                0
# License               0
# Gear                  0
# Glass                 0
# Power                 0
# Meter              1941
# Passengers          777
# Payment               0
# Sale                  0
# Previous_owners    1650
# Additions           501
# dtype: int64

# %%
df.hist(bins=60, figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Power'}>, <Axes: >]], dtype=object)

# %%
df['Additions'].fillna('Unknown', inplace=True)

# %%
df.dtypes
# Out:
# Car                 object
# Year               float64
# Price              float64
# Color               object
# Fuel                object
# Origin              object
# License             object
# Gear                object
# Glass               object
# Power              float64
# Meter               object
# Passengers          object
# Payment             object
# Sale                object
# Previous_owners     object
# Additions           object
# dtype: object

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce').astype('Int64')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').astype('Int64')
df['Power'] = pd.to_numeric(df['Power'], errors='coerce').astype('Int64')

# %%
df.to_csv('./data/CSV/data.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('./data/CSV/data.csv')

# %%
columns_of_interest = ['Passengers']

for column in columns_of_interest:
    unique_values = df[column].unique()[:10000]
    print(f"{column}: {unique_values}")
# Out:
# Passengers: ['4+1' '7+1' nan '5+1' '٤+١' '8' '6+1' '4+١' '٧' '7,+ 1' '7:1' '1+7' '١+٤'
#  '2+1' '6+١' '+1' '6±١' '22' '1+1' '٥+١' '٧+1' '5+2' 'مثال: 4 + 1' '7.1'
#  '7 =1' '٧+١' '1+2' '6x1' '1+٤' '2/1' '8+1' '٨+١' '٦+١' '2' '4+2' '1٠4'
#  '4\\١' '000' '3+1' '1' 'اكثر من 10' '9+1']

# %%
df['Passengers'] = (
    df['Passengers']
    .str.replace(r'[^\d+]','')
    .replace({
        '٤+١': '4+1',
        '1+4': '4+1',
        '١+4': '4+1',
        '١+٤': '4+1',
        '4+١': '4+1',
        '1٠4': '4+1',
        '4\\١': '4+1',
        '4+2': '4+1',
        '1+٤': '4+1',
        '1+4': '4+1',
        '+1': '4+1',
        '1+3': '4+1',
        '3+1': '4+1',
        '000': '4+1',
        'مثال: 4 + 1': '4+1',
        '٧': '7+1',
        '7,+ 1': '7+1',
        '7:1': '7+1',
        '1+7': '7+1',
        '7.1': '7+1',
        '7 =1': '7+1',
        '٧+١': '7+1',
        '8': '7+1',
        '1+٧': '7+1',
        '٧+1': '7+1',
        '6±١': '6+1',
        '6+١': '6+1',
        '6+1': '6+1',
        '5+2': '6+1',
        '6x1': '6+1',
        '٦+١': '6+1',
        '٥+١': '6+1',
        '1+2': '2+1',
        '2/1': '2+1',
        '2': '2+1',
        '2+1': '2+1',
        '1+1': '2+1',
        '1': '2+1',
        '٨+١': '8+1',
        'اكثر من 10': '10+1',
        '22': '10+1'      
    })
)

# %%
columns_of_interest = ['Previous_owners']

for column in columns_of_interest:
    unique_values = df[column].unique()[:5]
    print(f"{column}: {unique_values}")
# Out:
# Previous_owners: ['يد اولى' '2' nan '00' '0']

# %%
df['Previous_owners'] = (
    df['Previous_owners']
    .replace({
        'يد اولى': '1',
        'أولى': '1',
        'يد اولا': '1',
        'يد أولى': '1',
        'اولى': '1',
        'يد أولى استيراد': '1',
        'يد اولي 1': '1',
        'يد 1': '1',
        '١': '1',
        'يداولى': '1',
        'يد أولى وكالة': '1',
        'يدو اولى': '1',
        'يد واله': '1',
        'اول': '1',
        'يد ولا': '1',
        'يد اولى شركة': '1',
        'يد. اولى': '1',
        'ياولى': '1',
        'يد اول': '1',
        'يد اولى وكالة': '1',
        'يد اولى  اصل شركة': '1',
        'يد اولي': '1',
        'يد اولى اصحاب سابقون 0': '1',
        'اوله': '1',
        'يداولا': '1',
        'وارد كوريا يد اولى': '1',
        'يد ولى': '1',
        'يد اولى صفر كيلو': '1',
        'مستورده يد اولى': '1',
        'ايد اولى': '1',
        'يد أولئ أصحاب سابقون صفر': '1',
        'يد اولى / استيراد': '1',
        '1 أولى': '1',
        'ايد اوله': '1',
        'مستوردة يد اولى': '1',
        'يد اولى من الشركة المتحدة': '1'
    })
)

# %%
df.to_csv('./data/CSV/data.csv', index=False)

# %%
df = pd.read_csv('./data/CSV/data.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = df.select_dtypes(include=['number'])

sns.pairplot(numeric_data)
plt.show()

corr_matrix = numeric_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df.dtypes
# Out:
# Car                object
# Year                int64
# Price               int64
# Color              object
# Fuel               object
# Origin             object
# License            object
# Gear               object
# Glass              object
# Power               int64
# Meter              object
# Passengers         object
# Payment            object
# Sale               object
# Previous_owners    object
# Additions          object
# dtype: object

# %%
df['Passengers'] = df['Passengers'].apply(lambda x: sum(map(int, str(x).split('+'))) if isinstance(x, str) else x)


df.to_csv('./data/CSV/data.csv', index=False)

# %%
columns_of_interest = ['Passengers']

for column in columns_of_interest:
    unique_values = df[column].unique()[:10000]
    print(f"{column}: {unique_values}")
# Out:
# Passengers: [ 5.  8. nan  6.  7.  3. 11.  9. 10.]

# %%
df.isna().sum()
# Out:
# Car                   0
# Year                  0
# Price                 0
# Color                 0
# Fuel                  0
# Origin                0
# License               0
# Gear                  0
# Glass                 0
# Power                 0
# Meter              1941
# Passengers          777
# Payment               0
# Sale                  0
# Previous_owners    1650
# Additions             0
# dtype: int64

# %%
mean_passengers = df['Passengers'].mean()
df['Passengers'] = df['Passengers'].fillna(mean_passengers).astype(int)

# %%
df.to_csv('./data/CSV/data.csv', index=False)

# %%
df.dtypes
# Out:
# Car                object
# Year                int64
# Price               int64
# Color              object
# Fuel               object
# Origin             object
# License            object
# Gear               object
# Glass              object
# Power               int64
# Meter              object
# Passengers          int32
# Payment            object
# Sale               object
# Previous_owners    object
# Additions          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Car                   0
# Year                  0
# Price                 0
# Color                 0
# Fuel                  0
# Origin                0
# License               0
# Gear                  0
# Glass                 0
# Power                 0
# Meter              1941
# Passengers            0
# Payment               0
# Sale                  0
# Previous_owners    1650
# Additions             0
# dtype: int64

# %%
df.to_csv('./data/CSV/data.csv', index=False)
